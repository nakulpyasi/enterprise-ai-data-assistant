# %%
from enterprise_ai_data_assistant.config import settings
from enterprise_ai_data_assistant.services.foundry_agent_service import (
    FoundryAgentService,
)
sql_agent = FoundryAgentService(
    endpoint=settings.foundry_project_endpoint,
    agent_name=settings.foundry_sql_agent_name,
    agent_version=settings.foundry_sql_agent_version,
)
print("making request")
response = sql_agent.ask_sql_agent(
    "How many support tickets are there?"
)
print(response)
# Out:
# making request
# FINAL OUTPUT: [ResponseOutputMessage(id='msg_04b5271502c7d14b006a8e6fe0a5008194ad270bceb2309485', content=[ResponseOutputText(annotations=[], text='There are 5 support tickets in total.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None, agent_reference={'type': 'agent_reference', 'name': 'enterprise-sql-agent', 'version': '4'}, response_id='resp_04b5271502c7d14b006a8e6fdfd58481948f833b284981d502')]
# FINAL TEXT: 'There are 5 support tickets in total.'
# FINAL STATUS: completed
# There are 5 support tickets in total.

# %%
from enterprise_ai_data_assistant.services.orchestration_service import manager
import asyncio

# %%
manager.
